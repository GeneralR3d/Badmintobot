# %%
import numpy as np
import pandas as pd
import math

# %%
dataset= pd.read_excel("../VisionModel/preprocessing/datasetTBFilled.xlsx")
dataset.rename(columns={'LaunchX': 'diffX',
                        'LaunchY': 'diffY',
                        'LaunchZ': 'diffZ',
                        'LaunchAngle':'diffAngle',
                        'LaunchDirection':'diffDirection',
                        'InitialV': 'vDiff'
                        },inplace=True)

# %%
dataset
# Out:
#            time  LocationX  LocationY  LocationZ  diffX  diffY  diffZ  \
# 0      0.000000    1814.38      48.27    2639.32    NaN    NaN    NaN
# 1      0.033333    2578.94     184.52    3035.79    NaN    NaN    NaN
# 2      0.066667    3539.25     184.90    3617.66    NaN    NaN    NaN
# 3      0.100000    4362.40     192.19    4107.69    NaN    NaN    NaN
# 4      0.133333    5067.95     207.63    4518.10    NaN    NaN    NaN
# ...         ...        ...        ...        ...    ...    ...    ...
# 34277  1.866667   13988.46     805.71    3383.88    NaN    NaN    NaN
# 34278  1.900000   13970.23     800.95    3190.30    NaN    NaN    NaN
# 34279  1.933333   14025.55     814.37    2995.14    NaN    NaN    NaN
# 34280  1.966667   14078.77     807.79    2787.40    NaN    NaN    NaN
# 34281  2.000000   14218.24     820.35    2603.57    NaN    NaN    NaN
#
#        diffAngle  diffDirection  vDiff  label
# 0            NaN            NaN    NaN      1
# ...

# %%
currentDF=dataset[dataset['label']==2]
currentDF
# Out:
#          time  LocationX  LocationY  LocationZ  diffX  diffY  diffZ  \
# 59   0.000000    1897.75      16.87    2978.76    NaN    NaN    NaN
# 60   0.033333    2775.30      21.14    3446.83    NaN    NaN    NaN
# 61   0.066667    3500.78      20.08    3810.88    NaN    NaN    NaN
# 62   0.100000    4156.46      44.44    4147.31    NaN    NaN    NaN
# 63   0.133333    4730.41      61.98    4429.60    NaN    NaN    NaN
# 64   0.166667    5190.65      77.52    4640.69    NaN    NaN    NaN
# 65   0.200000    5595.52      89.78    4831.50    NaN    NaN    NaN
# 66   0.233333    6008.65      96.53    5015.25    NaN    NaN    NaN
# 67   0.266667    6382.62     117.52    5175.12    NaN    NaN    NaN
# 68   0.300000    6711.42     128.69    5305.04    NaN    NaN    NaN
# 69   0.333333    7005.04     132.57    5411.52    NaN    NaN    NaN
# 70   0.366667    7276.91     146.01    5510.53    NaN    NaN    NaN
# 71   0.400000    7585.56     160.48    5602.45    NaN    NaN    NaN
# ...

# %%
firstIndex = currentDF.index[0]
print(firstIndex)
print(len(currentDF))
# Out:
# 59
# 56

# %%
hello = pd.Series([currentDF['LocationX'][i+1] - currentDF['LocationX'][i] for i in range(firstIndex,firstIndex+len(currentDF)-1)])
#hello = hello.reindex(currentDF.index)

hello[hello.size]=0
hello.index=currentDF.index
hello
# Out:
# 59     877.55
# 60     725.48
# 61     655.68
# 62     573.95
# 63     460.24
# 64     404.87
# 65     413.13
# 66     373.97
# 67     328.80
# 68     293.62
# 69     271.87
# 70     308.65
# 71     315.18
# 72     338.82
# 73     285.07
# 74     115.93
# 75     134.12
# 76     316.78
# 77     172.89
# 78     289.94
# 79     114.95
# 80     194.36
# 81     227.44
# 82     163.59
# 83      55.11
# 84     173.68
# 85     118.20
# 86     188.98
# 87      13.58
# 88     356.40
# 89     157.90
# 90     140.04
# 91     140.85
# 92       9.46
# 93     153.28
# 94     155.26
# 95     139.93
# 96     169.36
# 97     -33.79
# 98      71.67
# 99     241.82
# 100     95.56
# 101    175.31
# 102    -51.04
# 103    262.13
# 104     25.42
# 105    -52.44
# 106     44.04
# 107    100.43
# 108    -93.18
# 109     98.76
# 110    179.32
# 111    101.35
# 112   -188.18
# 113    206.16
# 114      0.00
# dtype: float64

# %%
currentDF.index
# Out:
# Int64Index([ 59,  60,  61,  62,  63,  64,  65,  66,  67,  68,  69,  70,  71,
#              72,  73,  74,  75,  76,  77,  78,  79,  80,  81,  82,  83,  84,
#              85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#              98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
#             111, 112, 113, 114],
#            dtype='int64')

# %%
hello.reindex()

# %%
#currentDF = currentDF.assign(diffX=hello)
currentDF['diffX'] = hello
currentDF
# Out:
#          time  LocationX  LocationY  LocationZ   diffX  diffY  diffZ  \
# 59   0.000000    1897.75      16.87    2978.76  877.55    NaN    NaN
# 60   0.033333    2775.30      21.14    3446.83  725.48    NaN    NaN
# 61   0.066667    3500.78      20.08    3810.88  655.68    NaN    NaN
# 62   0.100000    4156.46      44.44    4147.31  573.95    NaN    NaN
# 63   0.133333    4730.41      61.98    4429.60  460.24    NaN    NaN
# 64   0.166667    5190.65      77.52    4640.69  404.87    NaN    NaN
# 65   0.200000    5595.52      89.78    4831.50  413.13    NaN    NaN
# 66   0.233333    6008.65      96.53    5015.25  373.97    NaN    NaN
# 67   0.266667    6382.62     117.52    5175.12  328.80    NaN    NaN
# 68   0.300000    6711.42     128.69    5305.04  293.62    NaN    NaN
# 69   0.333333    7005.04     132.57    5411.52  271.87    NaN    NaN
# 70   0.366667    7276.91     146.01    5510.53  308.65    NaN    NaN
# 71   0.400000    7585.56     160.48    5602.45  315.18    NaN    NaN
# ...
